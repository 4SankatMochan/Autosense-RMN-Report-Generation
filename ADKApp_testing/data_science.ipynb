# %%
import vertexai
import sys
project_root = os.path.abspath(os.path.join(os.getcwd(), '..'))
if project_root not in sys.path:
    sys.path.insert(0, project_root)

def artifact_service_builder():
  from google.adk.artifacts import GcsArtifactService
  return GcsArtifactService(bucket_name="acn-cda-adk-staging")
import os
os.environ["GOOGLE_GENAI_USE_VERTEXAI"] = "True"
os.environ["GOOGLE_CLOUD_PROJECT"] = "acn-cda"
os.environ["GOOGLE_CLOUD_LOCATION"] = "us-central1"
from vertexai.preview import reasoning_engines
from data_science.agent import root_agent as Main_Agent
app = reasoning_engines.AdkApp(
    agent=Main_Agent,
    artifact_service_builder= artifact_service_builder
)

# %%
import pprint
session = app.create_session(user_id = "user_p1")
session_id = session.id
print(f"session_id: {session_id}")
track = 0
que = "bar chart for sales across all the channels"
print(f"question: {que}")
for event in app.stream_query(user_id="user_p1",session_id=session_id,message=que):
        print("--------")
        try:
            print(event["content"]["parts"][0]["text"])
        except:
            pass
        print("*******")
# Out:
# session_id: acfa6b81-8dd0-44df-a2ad-abbc7332b4a9
# question: bar chart for sales across all the channels
# --------
# *******
# ...
# --------
#  call_db_agent.use_database: BigQuery
#
# *******
# ...
#  sql: SELECT
#     t2.channels,
#     SUM(t1.order_amount) AS total_sales
#   FROM
#     `acn-cda.RMN_Campaign_Dataset_Dev.transaction_data` AS t1
#     INNER JOIN `acn-cda.RMN_Campaign_Dataset_Dev.campaign_performance` AS t2 ON t1.campaign_id = t2.campaign_id
#   GROUP BY
#     t2.channels
#   ORDER BY
#     total_sales DESC
#   LIMIT 500
# ...
#  run_bigquery_validation final_result:
#  {'query_result': [{'channels': 'Onsite', 'total_sales': 21398915}, {'channels': 'Offsite', 'total_sales': 18539159}, {'channels': 'App', 'total_sales': 15156202}, {'channels': 'Channel-CTV', 'total_sales': 5142060}, {'channels': 'In-store', 'total_sales': 2672419}], 'error_message': None}
# ...
